# %% [markdown]
# ![python%20image.jpg](attachment:python%20image.jpg)

# %% [markdown]
# # Python Modules

# %% [markdown]
# One of Python's strenghts
#
# Module = A simple python file (.py)
# - Python Object
# - Normally includes: Global variable and executable code

# %% [markdown]
# Adding a "requirements.txt" file helps when collaborating on a project that is using multiple modules:
# - Flask: Flask is a micro web framework for Python
# - IpInfo: Allows python to access the IpInfo.io IP Address API and get information on IP geolocation

# %% [markdown]
# ### Creating a requirements file:

# %%
with open("requirements.txt","w+") as file:
    file.write("flask==1.1.2\n" + "ipinfo==4.1.0\n")
    file.close()

# %% [markdown]
# #### requirements.txt Content:

# %% [raw]
# flask==1.1.2
# ipinfo==4.1.0

# %% [markdown]
# #### Colleborators can run now ensure they have the correct version installed

# %%
pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: cachetools in e:\anaconda\lib\site-packages (from ipinfo==4.1.0->-r requirements.txt (line 2)) (4.2.0)
# ...
#
# ...

# %% [markdown]
# ## Using a Module

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def home():
    return 'Hello Introduction to Python Exam!'

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)

# %%
import ipinfo
access_token = '7cbab5e79a7af4'
handler = ipinfo.getHandler(access_token)
details = handler.getDetails()
#print(details.all)

# %% [markdown]
# ### Behind the scenes of getDetails()

# %% [raw]
# def getDetails(self, ip_address=None, timeout=None):
#     # If the supplied IP address uses the objects defined in the built-in
#     # module ipaddress extract the appropriate string notation before
#     # formatting the URL.
#     if isinstance(ip_address, IPv4Address) or isinstance(ip_address, IPv6Address):
#         ip_address = ip_address.exploded
#
#     if ip_address in self.cache:
#         return Details(self.cache[ip_address])
#
#     # prepare req http opts
#     req_opts = {**self.request_options}
#     if timeout is not None:
#         req_opts["timeout"] = timeout
#
#     # not in cache; do http req
#     url = API_URL
#     if ip_address:
#         url += "/" + ip_address
#     headers = handler_utils.get_headers(self.access_token)
#     response = requests.get(url, headers=headers, **req_opts)
#     if response.status_code == 429:
#         raise RequestQuotaExceededError()
#     response.raise_for_status()
#     details = response.json()
#
#     # format & cache
#     handler_utils.format_details(details, self.countries)
#     self.cache[ip_address] = details
#
#     return Details(details)

# %% [markdown]
# #  Python Development Envoirments

# %% [markdown]
# Python development envoiments are very versatile and it can run on and with almost anything:
# - REPL (Read, Evaluate, Print, loop)
# - Jupyter
# - Docker
# - PyCharm
# - VS Code

# %% [markdown]
# ## REPL

# %% [markdown]
# ![REPL%20example.PNG](attachment:REPL%20example.PNG)

# %% [raw]
# E:\Anaconda\python.exe

# %% [markdown]
# ## Jupyter Notebooks

# %% [markdown]
# A "Computational engine" that executes the code contained in a Notebook document.
#
# When a Notebook document is opened, the associated kernel is automatically launched, that executes the computation of the code.
#
# Jupyter = REPL + Kernel

# %%
x = 5*19
x
# Out:
# 95

# %%
def hello_Claus():
    print ('Hello Claus!')
    
hello_Claus()
# Out:
# Hello Claus!

# %% [markdown]
# ## Docker

# %% [markdown]
# Gives you an isolated envoirment for the python script to run on its own
#
# No version issues, since the container will always run with the specified version

# %% [markdown]
# ### Dockerfile Content

# %% [raw]
# FROM python
#
# COPY requirements.txt /app/setup/requirements.txt
# WORKDIR /app/setup
# RUN pip install -r requirements.txt
#
# COPY app.py /app/app.py
# COPY templates/. /app/templates
# WORKDIR /app
#
# EXPOSE 5000/tcp
#
# ENTRYPOINT ["python"]
# CMD ["app.py"]

# %% [markdown]
# ### app.py content:

# %%
from flask import Flask
from flask import render_template
import ipinfo

app = Flask(__name__)

@app.route('/')
def home():
    return render_template('index.html')

@app.route('/api/ipinfo')
def ip():
    access_token = '7cbab5e79a7af4'
    handler = ipinfo.getHandler(access_token)
    details = handler.getDetails()
    return details.all

if __name__ == '__main__':
    app.run(debug=True, host='0.0.0.0')
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
#  * Restarting with windowsapi reloader
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# E:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:3351: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## Docker Commands:

# %% [raw]
# docker build . -t flask_app_image

# %% [raw]
# docker run -it --rm --name flask_app -p 8080:5000 flask_app_image

# %% [markdown]
# General Commands:

# %% [raw]
# docker run -it --rm ubuntu

# %% [raw]
# docker run -it --rm python bash

# %% [raw]
# docker run -it --rm -v ${PWD}:/docs python bash

# %% [markdown]
# # Extra:

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 10.0, 0.01)
s = np.sin(2*np.pi*t)
plt.plot(t, s)

plt.xlabel('x')
plt.ylabel('y')
plt.title('A simple Sin-Graph')
plt.grid(True)
plt.savefig("test.png")
plt.show()
